# %%
# %matplotlib inline
from bokeh.plotting import figure, show, output_notebook

# %% [markdown]
# # Linear Regression Example
#
# This example uses the only the first feature of the `diabetes` dataset, in
# order to illustrate a two-dimensional plot of this regression technique. The
# straight line can be seen in the plot, showing how linear regression attempts
# to draw a straight line that will best minimize the residual sum of squares
# between the observed responses in the dataset, and the responses predicted by
# the linear approximation.
#
# The coefficients, the residual sum of squares and the variance score are also
# calculated.

# %%
print(__doc__)


# Code source: Jaques Grobler
# License: BSD 3 clause


import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model

# Load the diabetes dataset
diabetes = datasets.load_diabetes()


# Use only one feature
diabetes_X = diabetes.data

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes.target[:-20]
diabetes_y_test = diabetes.target[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((regr.predict(diabetes_X_test) - diabetes_y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(diabetes_X_test, diabetes_y_test))
# Out:
# Automatically created module for IPython interactive environment
# ('Coefficients: \n', array([  3.03499549e-01,  -2.37639315e+02,   5.10530605e+02,
#          3.27736980e+02,  -8.14131709e+02,   4.92814588e+02,
#          1.02848452e+02,   1.84606489e+02,   7.43519617e+02,
#          7.60951722e+01]))
# Mean squared error: 2004.57
# Variance score: 0.59

# %%
output_notebook()
p = figure()
p.scatter(diabetes_X_test.ravel(),diabetes_y_test)
p.line(diabetes_X_test.ravel(), regr.predict(diabetes_X_test))
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="10cf8a3c-0f75-434c-b7ba-0401c04370d6">Loading BokehJS ...</span>
#     </div>
# D:\Program Files\Anaconda2\lib\site-packages\bokeh\models\sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 200), ('y', 20)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# D:\Program Files\Anaconda2\lib\site-packages\bokeh\models\sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 200), ('y', 20)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cb4e75ca-1097-41ca-be86-347b06ddbb32"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cb4e75ca-1097-41ca-be86-347b06ddbb32");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cb4e75ca-1097-41ca-be86-347b06ddbb32");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cb4e75ca-1097-41ca-be86-347b06ddbb32' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d5aedaa8-7116-4e1c-8e77-6c3ed425ec54":{"roots":{"references":[{"attributes":{},"id":"a0258fe7-ff87-436c-a8d4-f899f87e3a02","type":"ToolEvents"},{"attributes":{"formatter":{"id":"1d59bd6a-2daa-4421-9a8f-d497a8233fb0","type":"BasicTickFormatter"},"plot":{"id":"86f5f92c-3c51-44b7-a4e8-5d23fa496dd6","subtype":"Figure","type":"Plot"},"ticker":{"id":"028c3232-d24a-4747-a8ac-2a336e499291","type":"BasicTicker"}},"id":"0bc063da-40ae-4fa8-aa98-4692e1529bd9","type":"LinearAxis"},{"attributes":{"plot":{"id":"86f5f92c-3c51-44b7-a4e8-5d23fa496dd6","subtype":"Figure","type":"Plot"}},"id":"916422c7-b4bb-4d80-abdc-90fb6fbc61d1","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"T1uof8qzaEA2wVjJEm5jQN4l6XJfnGVALxs3jEPiW0BVwX4WnplkQIiRTL45YmBA2ns5QvUxcEAACTOyrR5ZQMp3d8PYQ11APs7Rs4UTX0CyTlf1uEtrQKKZqFBimU5ABhFx1AOIYECXmw+qVBVeQNodIga1RUpAjn2vIzdBaECgSNHEkaRZQFNfOCk65F5AVwLysxthakDSUy/LOk1KQA==","dtype":"float64","shape":[20]}}},"id":"ed1c5080-46e8-4c1a-bb66-2fe4efa7314b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ed1c5080-46e8-4c1a-bb66-2fe4efa7314b","type":"ColumnDataSource"},"glyph":{"id":"26f113fd-c1e8-4cae-9123-11563b22c7c0","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7533e80c-dac6-4e3c-8012-b65dad4c7347","type":"Line"},"selection_glyph":null},"id":"faa3aeee-a265-47e9-a8fe-e65ad4097fe4","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"727919ac-ed68-4598-8966-cbdd4aa10477","type":"BoxAnnotation"},"plot":{"id":"86f5f92c-3c51-44b7-a4e8-5d23fa496dd6","subtype":"Figure","type":"Plot"}},"id":"08acf896-6965-4e40-87ee-ed1f7cd12521","type":"BoxZoomTool"},{"attributes":{},"id":"0dd878d8-274d-4e82-bb9b-ad9fc3aa7567","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"86f5f92c-3c51-44b7-a4e8-5d23fa496dd6","subtype":"Figure","type":"Plot"}},"id":"1ebe549e-f27f-405d-b576-70d17af63a0d","type":"PanTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"AAAAAAAgbUAAAAAAAMBWQAAAAAAAwFtAAAAAAAAAY0AAAAAAAABeQAAAAAAAwFBAAAAAAABgc0AAAAAAAIBXQAAAAAAA4GZAAAAAAACAUEAAAAAAAKBlQAAAAAAAAFJAAAAAAACASEAAAAAAAABQQAAAAAAAAEhAAAAAAABAZkAAAAAAAABaQAAAAAAAgGBAAAAAAACAa0AAAAAAAIBMQA==","dtype":"float64","shape":[20]}}},"id":"baa03eb0-34a9-4d65-b6bb-4ab438cc94d8","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"86f5f92c-3c51-44b7-a4e8-5d23fa496dd6","subtype":"Figure","type":"Plot"}},"id":"2cfa8132-9e49-4cd5-a4bb-58c15930ee24","type":"ResetTool"},{"attributes":{},"id":"d5c3e200-7390-4fdc-baf1-f1b79f3522da","type":"LinearScale"},{"attributes":{"plot":{"id":"86f5f92c-3c51-44b7-a4e8-5d23fa496dd6","subtype":"Figure","type":"Plot"}},"id":"9069c718-006e-43e6-9508-0efa0eaf2085","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"727919ac-ed68-4598-8966-cbdd4aa10477","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"0bc063da-40ae-4fa8-aa98-4692e1529bd9","type":"LinearAxis"}],"left":[{"id":"6329f14d-37d3-462e-bd34-3ef8dc92818b","type":"LinearAxis"}],"renderers":[{"id":"0bc063da-40ae-4fa8-aa98-4692e1529bd9","type":"LinearAxis"},{"id":"e0802f80-fbd7-469a-98ad-6ad6d7039b80","type":"Grid"},{"id":"6329f14d-37d3-462e-bd34-3ef8dc92818b","type":"LinearAxis"},{"id":"ac966a04-ca69-40ec-bf8e-6fa021da486a","type":"Grid"},{"id":"727919ac-ed68-4598-8966-cbdd4aa10477","type":"BoxAnnotation"},{"id":"54e117ec-b89e-4f35-8156-13f160a1b079","type":"GlyphRenderer"},{"id":"faa3aeee-a265-47e9-a8fe-e65ad4097fe4","type":"GlyphRenderer"}],"title":{"id":"aa2e63da-49e7-4bbb-af56-f9cd57bdccf6","type":"Title"},"tool_e ...

# %%
for a in np.linspace(0,1,11):
    ridge_model = linear_model.Ridge(alpha=a)
    ridge_model.fit(diabetes_X_train, diabetes_y_train)
    print 'alpha = %f' % a
    print 'score = %f' % ridge_model.score(diabetes_X_test,diabetes_y_test)
    print 'MSE = %f' % np.mean((ridge_model.predict(diabetes_X_test) - diabetes_y_test)**2)
# Out:
# alpha = 0.000000
# score = 0.585075
# MSE = 2004.567603
# alpha = 0.100000
# score = 0.570590
# MSE = 2074.548443
# alpha = 0.200000
# score = 0.553680
# MSE = 2156.243186
# alpha = 0.300000
# score = 0.537260
# MSE = 2235.571331
# alpha = 0.400000
# score = 0.521550
# MSE = 2311.466811
# alpha = 0.500000
# score = 0.506610
# MSE = 2383.646911
# alpha = 0.600000
# score = 0.492431
# MSE = 2452.146394
# alpha = 0.700000
# score = 0.478979
# MSE = 2517.137150
# alpha = 0.800000
# score = 0.466206
# MSE = 2578.845203
# alpha = 0.900000
# score = 0.454063
# MSE = 2637.510602
# alpha = 1.000000
# score = 0.442501
# MSE = 2693.368042

# %%
ridgeCV = linear_model.RidgeCV()
