# %%
# %matplotlib inline

# %% [markdown]
# # Plot Ridge coefficients as a function of the regularization
#
#
# Shows the effect of collinearity in the coefficients of an estimator.
#
# .. currentmodule:: sklearn.linear_model
#
# :class:`Ridge` Regression is the estimator used in this example.
# Each color represents a different feature of the
# coefficient vector, and this is displayed as a function of the
# regularization parameter.
#
# This example also shows the usefulness of applying Ridge regression
# to highly ill-conditioned matrices. For such matrices, a slight
# change in the target variable can cause huge variances in the
# calculated weights. In such cases, it is useful to set a certain
# regularization (alpha) to reduce this variation (noise).
#
# When alpha is very large, the regularization effect dominates the
# squared loss function and the coefficients tend to zero.
# At the end of the path, as alpha tends toward zero
# and the solution tends towards the ordinary least squares, coefficients
# exhibit big oscillations. In practise it is necessary to tune alpha
# in such a way that a balance is maintained between both.

# %%
# Author: Fabian Pedregosa -- <fabian.pedregosa@inria.fr>
# License: BSD 3 clause

print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# X is the 10x10 Hilbert matrix
X = 1. / (np.arange(1, 11) + np.arange(0, 10)[:, np.newaxis])
y = np.ones(10)
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# Compute paths

# %%
n_alphas = 200
alphas = np.logspace(-10, -2, n_alphas)
clf = linear_model.Ridge(fit_intercept=False)

coefs = []
for a in alphas:
    clf.set_params(alpha=a)
    clf.fit(X, y)
    coefs.append(clf.coef_)

# %%
ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.show()

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.charts import Line

# %%
coefs.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f941cad49150> in <module>()
# ----> 1 coefs[:,1]
#
# TypeError: list indices must be integers, not tuple

# %%
output_notebook()

p = figure()

p.line(alphas, coefs[0])

p.axis.

show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
#     <div class="plotdiv" id="fd1276bd-055b-48ef-b11d-4ff2f337ffd0"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fd1276bd-055b-48ef-b11d-4ff2f337ffd0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fd1276bd-055b-48ef-b11d-4ff2f337ffd0' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bf5eefb2-d03c-4ceb-b91c-1128e7f6a247": {"version": "0.11.0", "roots": {"root_ids": ["25bfa7eb-6106-41ba-b1fe-f9cbff9226da", "0823641d-32e7-4632-996c-c059403e007b", "2e4931d4-c59c-4153-83f6-efcdba2f6f95"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "25bfa7eb-6106-41ba-b1fe-f9cbff9226da"}}, "type": "WheelZoomTool", "id": "ed6f0fb5-5a9e-4ba0-8a25-06fd5a6bf012"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "25bfa7eb-6106-41ba-b1fe-f9cbff9226da"}, "ticker": {"type": "BasicTicker", "id": "f32a1e96-4db9-40e7-81a6-88b86a120c95"}, "dimension": 1}, "type": "Grid", "id": "6e8c80cc-1c80-4a7b-b9a4-1824aa28f135"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0823641d-32e7-4632-996c-c059403e007b"}, "formatter": {"type": "BasicTickFormatter", "id": "4cccd968-b4de-4bec-99de-4940cfbcab9a"}, "ticker": {"type": "BasicTicker", "id": "39c5f118-0963-47cc-ade3-768de0b76a9a"}}, "type": "LinearAxis", "id": "c26fab47-3632-4280-a0ec-1de856b8cc92"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "0823641d-32e7-4632-996c-c059403e007b"}}, "type": "ResetTool", "id": "9dcd6d9b-9597-41f4-9793-7a5b0b59ec4f"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "25bfa7eb-6106-41ba-b1fe-f9cbff9226da"}, "formatter": {"type": "BasicTickFormatter", "id": "4f9230aa-f288-4d93-bfe5-fc9d1125dc64"}, "ticker": {"type": "BasicTicker", "id": "f32a1e96-4db9-40e7-81a6-88b86a120c95"}}, "type": "LinearAxis", "id": "c861b3fa-93d8-4adc-8b33-d252e6f94ac9"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "b1b144c8-7e9e-4e08-bbca-6323396aadb2"}, "y_range": {"type": "DataRange1d", "id": "ea37207a-18b8-442a-b4e4-e160472b240c"}, "renderers": [{"type": "LinearAxis", "id": "c2f50c96-ddc6-4e16-a4f0-2f982d753211"}, {"type": "Grid", "id": "98573f78-2de9-4094-900a-276197f2ff31"}, {"type": "LinearAxis", "id": "c861b3fa-93d8-4adc-8b33-d252e6f94ac9"}, {"type": "Grid", "id": "6e8c80cc-1c80-4a7b-b9a4-1824aa28f135"}, {"type": "BoxAnnotation", "id": "8dac70af-67e4-49da-ae0f-6109b43342d5"}], "below": [{"type": "LinearAxis", "id": "c2f50c96-ddc6-4e16-a4f0-2f982d753211"}], "tool_events": {"type": "ToolEvents", "id": "c465187f-80fe-42f3-9f23-194f09b14bc4"}, "tools": [{"type": "PanTool", "id": "a34c7647-70ae-45b6-92f6-a0ec9c747e9c"}, {"type": "WheelZoomTool", "id": "ed6f0fb5-5a9e-4ba0-8a25-06fd5a6bf012"}, {"type": "BoxZoomTool", "id": "4a45efa5-186f-4b64-bd36-793ab978752d"}, {"type": "PreviewSaveTool", "id": "e3cfbd2d-f7d1-47e0-add0-ac12af28c8ad"}, {"type": "ResizeTool", "id": "16c02b0d-872a-456a-a8e1-6d1aef6efa59"}, {"type": "ResetTool", "id": "49625195-c322-4e9d-b51d-0a9d49b7a605"}, {"type": "HelpTool", "id": "56cdd103-d34b-40d9-84c8-c16677b0ae2e"}], "left": [{"type": "LinearAxis", "id": "c861b3fa-93d8-4adc-8b33-d252e6f94ac9"}]}, "type": "Plot", "id": "25bfa7eb-6106-41ba-b1fe-f9cbff9226da", "subtype": "Figure"}, {"attributes": {}, "type": "BasicTicker", "id": "2283882b-c8e8-4f29-8029-744fabe06bbd"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "2e4931d4-c59c-4153-83f6-efcdba2f6f95"}, "formatter": {"type": "BasicTickFormatter", "id": "2d740ad6-99ee-45b2-b5f8-d70b34a5de45"}, "ticker": {"type": "BasicTicker", "id": "898c4709-e477-4bd6-9b0f-f366dbc9946c"}}, "type": "LinearAxis", "id": "7b2403eb-7e9b-4845-9088-c4c637e51b73"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "031b6e6d-1020-40ca-8c01-35db91dd54d2"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "2e4931d4-c59c-4153-83f6-efcdba2f6f95"}}, "type": "ResetTool", "id": "008767cc-78ed-4e70-95da-becb05b53e61"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [[2.6450619698146145, -27.603709078201497, 7.992886358954074, 133.67547645735894, 18.043269184472475, -123.85509757433317, -175.62007193460073, -113.78631299414278, 45.153822743949554, 274.02301146766524], [2.774952718679671, -30.1209786411467, 17. ...
